# %% [markdown]
# # ML in MD
# ## Result for strategy BuyNHoldStrategy taken as market
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |           6.08 |           6.08 |       0.00304344 |           0.09 | 29 days, 23:38:00 |        1 |      0 |
# | TOTAL    |           1 |           6.08 |           6.08 |       0.00304344 |           0.09 | 29 days, 23:38:00 |        1 |      0 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT :
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |           6.08 |           6.08 |       0.00304344 |           0.09 | 29 days, 23:38:00 |        1 |      0 |
# | TOTAL    |           1 |           6.08 |           6.08 |       0.00304344 |           0.09 | 29 days, 23:38:00 |        1 |      0 |

# %% [markdown]
# ## 30.11.2019. First result beating the market
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration     |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:-----------------|---------:|-------:|
# | BTC/USDT |           8 |           1.24 |           9.94 |       0.00497314 |           0.14 | 3 days, 17:54:00 |        7 |      1 |
# | TOTAL    |           8 |           1.24 |           9.94 |       0.00497314 |           0.14 | 3 days, 17:54:00 |        7 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | roi           |       7 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
# | TOTAL    |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
#
# Got that with:

# %%
minimal_roi = {
        # "1440": 0.01,
        "80": 0.02,
        "40": 0.03,
        "20": 0.04,
        "0":  0.05
    }
stoploss = -0.90
self.to_drop = ['date',
                        'volume',
                        # 'close_to_sma',
                        'high', 'low',
                        'open', 'close',
                        # 'macd',
                        'macdsignal',
                        # 'minus_di',
                        # 'TRANGE'
                        # 'rsi',
                        'fisher_rsi', 'fisher_rsi_norma',
                        # 'fastd', 'fastk',
                        # 'sar', 'sma'
                        ]
from sklearn.preprocessing import MinMaxScaler

df_filtered = df.drop(self.to_drop, axis=1)
self.fr_features = ['minus_di', 'rsi', 'fastd', 'fastk', 'sar', 'sma', 'TRANGE']
self.neg_features = ['macd']
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=4, p=1, weights="distance")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1711b6962ab> in <module>
#      17                         # 'TRANGE'
#      18                         # 'rsi',
# ---> 19                         'fisher_rsi', 'fisher_rsi_norma',
#      20                         # 'fastd', 'fastk',
#      21                         # 'sar', 'sma'
#
# NameError: name 'self' is not defined

# %% [markdown]
# ## 30.11.2019. Second result beating the market
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration    |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:----------------|---------:|-------:|
# | BTC/USDT |           9 |           1.30 |          11.68 |       0.00584517 |           0.17 | 3 days, 7:53:00 |        8 |      1 |
# | TOTAL    |           9 |           1.30 |          11.68 |       0.00584517 |           0.17 | 3 days, 7:53:00 |        8 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | roi           |       8 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -14.30 |         -14.30 |      -0.00715483 |          -0.20 | 19 days, 20:02:00 |        0 |      1 |
# | TOTAL    |           1 |         -14.30 |         -14.30 |      -0.00715483 |          -0.20 | 19 days, 20:02:00 |        0 |      1 |
#
# Got that with:

# %%
minimal_roi = {
        # "1440": 0.01,
        "80": 0.02,
        "40": 0.03,
        "20": 0.04,
        "0":  0.05
    }
stoploss = -0.90
self.to_drop = ['date',
                        'volume',
                        # 'close_to_sma',
                        'high', 'low',
                        'open', 'close',
                        # 'macd',
                        'macdsignal',
                        # 'minus_di',
                        # 'TRANGE'
                        # 'rsi',
                        'fisher_rsi', 'fisher_rsi_norma',
                        # 'fastd', 'fastk',
                        # 'sar', 'sma'
                        ]
from sklearn.preprocessing import MinMaxScaler

df_filtered = df.drop(self.to_drop, axis=1)
self.fr_features = ['minus_di', 'rsi', 'fastd', 'fastk', 'sar', 'sma', 'TRANGE']
self.neg_features = ['macd']

from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor(alpha=0.85,
                                  learning_rate=0.9,
                                  loss="huber",
                                  max_depth=8,
                                #   max_features=0.8500000000000001,
                                #   min_samples_leaf=1,
                                #   min_samples_split=14,
                                  n_estimators=10,
                                #   subsample=0.55
                                  )

# %% [markdown]
# ## 1.12.2019 First XGB result
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration     |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:-----------------|---------:|-------:|
# | BTC/USDT |           8 |           1.07 |           8.57 |       0.00428929 |           0.12 | 3 days, 17:53:00 |        7 |      1 |
# | TOTAL    |           8 |           1.07 |           8.57 |       0.00428929 |           0.12 | 3 days, 17:53:00 |        7 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | roi           |       7 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
# | TOTAL    |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
#
# Got that with:

# %%
import xgboost as xgb
model = xgb.XGBRegressor(alpha=0.85,
                         learning_rate=0.9,
                         loss="huber",
                         max_depth=8,
                    #   max_features=0.8500000000000001,
                    #   min_samples_leaf=1,
                    #   min_samples_split=14,
                         n_estimators=10,
                    #   subsample=0.55
                         )

# %% [markdown]
# # 03.12.2019 Working on parameter tuning
# ![newplot.png](attachment:newplot.png)
# ![newplot%281%29.png](attachment:newplot%281%29.png)
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration     |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:-----------------|---------:|-------:|
# | BTC/USDT |           8 |           0.91 |           7.25 |       0.00363077 |           0.10 | 3 days, 17:52:00 |        7 |      1 |
# | TOTAL    |           8 |           0.91 |           7.25 |       0.00363077 |           0.10 | 3 days, 17:52:00 |        7 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | roi           |       7 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -14.30 |         -14.30 |      -0.00715483 |          -0.20 | 19 days, 20:02:00 |        0 |      1 |
# | TOTAL    |           1 |         -14.30 |         -14.30 |      -0.00715483 |          -0.20 | 19 days, 20:02:00 |        0 |      1 |
#
# Got that with

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor(alpha=0.9,
                                  learning_rate=0.9,
                                  loss="huber",
                                  max_depth=8,
                                #   max_features=0.8500000000000001,
                                #   min_samples_leaf=1,
                                #   min_samples_split=14,
                                  n_estimators=20,
                                #   subsample=0.55
                                  )

# %% [markdown]
# # 03.12.2019 Working on parameter tuning, KNRegressor with full set of data:
# self.to_drop = ['date',
#                         # 'volume',
#                         # 'close_to_sma',
#                         # 'high', 'low',
#                         # 'open', 'close',
#                         # 'macd',
#                         'macdsignal',
#                         # 'minus_di',
#                         # 'TRANGE'
#                         # 'rsi',
#                         'fisher_rsi', 'fisher_rsi_norma',
#                         # 'fastd', 'fastk',
#                         # 'sar', 'sma'
#                         ]
# from sklearn.preprocessing import MinMaxScaler
#
# df_filtered = df.drop(self.to_drop, axis=1)
# self.fr_features = ['high', 'low', 'open', 'close', 'volume', 'minus_di', 'rsi', 'fastd', 'fastk', 'sar', 'sma', 'TRANGE']
# self.neg_features = ['macd']
#
# ![newplot%282%29.png](attachment:newplot%282%29.png)
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration     |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:-----------------|---------:|-------:|
# | BTC/USDT |           8 |           1.24 |           9.94 |       0.00497314 |           0.14 | 3 days, 17:54:00 |        7 |      1 |
# | TOTAL    |           8 |           1.24 |           9.94 |       0.00497314 |           0.14 | 3 days, 17:54:00 |        7 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | roi           |       7 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
# | TOTAL    |           1 |         -13.23 |         -13.23 |      -0.00662051 |          -0.19 | 19 days, 20:06:00 |        0 |      1 |
#
# Got that with

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=3, p=2, weights="distance", n_jobs=4)

# %% [markdown]
# # 08.12.2019 JUST LOOK AT THIS GRAPH!
# ![look_at_this.png](attachment:look_at_this.png)
# got that after news analysis, see today's commit

# %% [markdown]
# # 11.12.2019 Model seem to be working
# Results with model above after strategy improvement (sell_profit_only: true). Buy count increased but still far from desirable. So is profit
#
#
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration   |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:---------------|---------:|-------:|
# | BTC/USDT |          57 |           0.15 |           8.66 |       0.00433266 |           0.00 | 12:37:00       |       56 |      1 |
# | TOTAL    |          57 |           0.15 |           8.66 |       0.00433266 |           0.00 | 12:37:00       |       56 |      1 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | sell_signal   |      56 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration      |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:------------------|---------:|-------:|
# | BTC/USDT |           1 |         -14.85 |         -14.85 |      -0.00743128 |          -0.00 | 19 days, 19:46:00 |        0 |      1 |
# | TOTAL    |           1 |         -14.85 |         -14.85 |      -0.00743128 |          -0.00 | 19 days, 19:46:00 |        0 |      1 |

# %% [markdown]
# # 12.12.2019 Tuning the strategy

# %%
stoploss = -0.085
# buy signal
delta = 0.1
(
    (dataframe['future_perc_change'] - dataframe['perc_change'] >= delta) &
    (dataframe['future_perc_change'] > 0)
),
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22e5c4c8faaa> in <module>
#       3 delta = 0.1
#       4 (
# ----> 5     (dataframe['future_perc_change'] - dataframe['perc_change'] >= delta) &
#       6     (dataframe['future_perc_change'] > 0)
#       7 ),
#
# NameError: name 'dataframe' is not defined

# %% [markdown]
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration   |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:---------------|---------:|-------:|
# | BTC/USDT |         210 |           0.10 |          20.89 |       0.01045771 |           0.00 | 3:23:00        |      205 |      5 |
# | TOTAL    |         210 |           0.10 |          20.89 |       0.01045771 |           0.00 | 3:23:00        |      205 |      5 |
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | sell_signal   |     205 |
# | stop_loss     |       4 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration    |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:----------------|---------:|-------:|
# | BTC/USDT |           1 |          -2.07 |          -2.07 |      -0.00103382 |          -0.00 | 2 days, 9:39:00 |        0 |      1 |
# | TOTAL    |           1 |          -2.07 |          -2.07 |      -0.00103382 |          -0.00 | 2 days, 9:39:00 |        0 |      1 |
#
# But prediction fails on high volumes:
# ![newplot%283%29.png](attachment:newplot%283%29.png)

# %% [markdown]
# # 14.12.2019 Now look at this report!
# BACKTESTING REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration   |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:---------------|---------:|-------:|
# | BTC/USDT |         514 |           0.23 |         117.46 |       0.05878935 |           0.00 | 0:18:00        |      513 |      1 |
# | TOTAL    |         514 |           0.23 |         117.46 |       0.05878935 |           0.00 | 0:18:00        |      513 |      1 |
#
#
# | Sell Reason   |   Count |
# |:--------------|--------:|
# | sell_signal   |     510 |
# | roi           |       3 |
# | force_sell    |       1 |
#
# LEFT OPEN TRADES REPORT:
#
# | pair     |   buy count |   avg profit % |   cum profit % |   tot profit BTC |   tot profit % | avg duration     |   profit |   loss |
# |:---------|------------:|---------------:|---------------:|-----------------:|---------------:|:-----------------|---------:|-------:|
# | BTC/USDT |           1 |          -3.45 |          -3.45 |      -0.00172805 |          -0.00 | 3 days, 17:17:00 |        0 |      1 |
# | TOTAL    |           1 |          -3.45 |          -3.45 |      -0.00172805 |          -0.00 | 3 days, 17:17:00 |        0 |      1 |
#
# Got that with:

# %%
(
                # (dataframe['future_perc_change'] - dataframe['perc_change'] >= delta) &
                (dataframe['future_perc_change'] > delta * 2)
            ),
            'buy'] = 1
